# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/SNN_Aspect_Term_Extraction/Main_Experiments/
# Out:
# /content/drive/MyDrive/SNN_Aspect_Term_Extraction/Main_Experiments

# %%
train_data_path = '../SemEval_Data/SemEval/SemEval14/Restaurants_Train.xml'
test_data_path = '../SemEval_Data/SemEval/SemEval14/Restaurants_Test_Data_phaseB.xml'

# %%
# !python main_v1.py --trainDataPath {train_data_path} --testDataPath {test_data_path} --batchSize 8 --seedNum 43 --epoch 20 --resetMechanism "zero" --spkNature "ternary" --numTimeSteps 6 --seqLen 82
# Out:
# Run number: 0
# Number of pochs: 20
# Batch size: 8
# Learning rate: 0.0001
# Number of classes: 3
# Time steps: 6
# Scdecay, Vdecay, Vth: [0.1, 0.1, 0.1]
# Spike nature (binary or ternary): ternary
# Vth is adaptive or not: 0
# Reset mechanism type: zero
# Sequence length: 82
# Embedding dimension: 300
# Number of output channels: 256
# Number of validation samples: 150
# Type of pre_embedding: glove
# Seed num: 43
# Number of runs: 3
# Training path: ../SemEval_Data/SemEval/SemEval14/Restaurants_Train.xml
# Test path: ../SemEval_Data/SemEval/SemEval14/Restaurants_Test_Data_phaseB.xml
#
# Device: cuda
#
# Total number of training samples: 9077
# Total number of validation samples: 150
# Total number of test samples: 800
#
#
# SNN Model Summary:
#
# CurrentBasedSNN(
#   (spikeate): SpikeATE(
#     (embedding): Embedding(10052, 300, padding_idx=0)
#     (conv_spk_enc): CurrentBasedLIF(
#       (func_v): Conv1d(300, 256, kernel_size=(5,), stride=(1,), padding=(2,))
# ...
